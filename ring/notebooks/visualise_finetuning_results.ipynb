# %%
import os
import json
import glob

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# precalculated_results_locs = glob.glob('/Users/walml/repos/zoobot/finetune_frozen*timestamped*.json')  # bad name, should have called precalculated
# precalculated_results = [json.load(open(loc)) for loc in precalculated_results_locs]

# %%
# precalculated_df = pd.DataFrame(data=precalculated_results)
# precalculated_df['method'] = 'precalulated'
# precalculated_df = precalculated_df.rename(columns={'dataset_size': 'train_dataset_size'})

# %%
# advanced_results_locs = glob.glob('/Users/walml/repos/zoobot/finetune_advanced*timestamped*.json')
# advanced_results = [json.load(open(loc)) for loc in advanced_results_locs]

# advanced_df = pd.DataFrame(data=advanced_results)

# advanced_df.head()

# %%
# frozen_df_first = advanced_df[advanced_df['run_name'].apply(lambda x: 'baseline' in x)]

# %%
# results_dir = '/Users/walml/repos/zoobot/results/training_data_experiment'
# results_dir = '/Users/walml/repos/zoobot/results'
results_dir = '/home/walml/repos/zoobot/results'

# %%
# # original paper results


# # im scratch is just scratch but in color...
# im_scratch_results_locs = glob.glob(os.path.join(results_dir, 'imagenet_scratch', 'imagenet_scratch_b256_1em5*scratch_result_timestamped*.json'))
# im_scratch_results = [json.load(open(loc)) for loc in im_scratch_results_locs]
# im_scratch_df = pd.DataFrame(data=im_scratch_results)
# im_scratch_df['method'] = 'Color Scratch'

# im_frozen_results_locs = glob.glob(os.path.join(results_dir, 'imagenet_finetune', 'imagenet_finetune_*_nocheat_b256_1em5*transfer_result_timestamped*.json'))
# im_frozen_results = [json.load(open(loc)) for loc in im_frozen_results_locs]
# im_frozen_df = pd.DataFrame(data=im_frozen_results)
# im_frozen_df['method'] = 'Imagenet Frozen'

# im_block4_results_locs = glob.glob(os.path.join(results_dir,'imagenet_finetune', 'imagenet_finetune_block4_nocheat_b256_1em5*_finetuned_result_timestamped*.json'))
# im_block4_results = [json.load(open(loc)) for loc in im_block4_results_locs]
# im_block4_df = pd.DataFrame(data=im_block4_results)
# im_block4_df['method'] = 'Imagenet Finetuned Block4+'

# # in progress
# im_block6_results_locs = glob.glob(os.path.join(results_dir, 'imagenet_finetune','imagenet_finetune_block6_nocheat_b256_1em5*_finetuned_result_timestamped*.json'))
# im_block6_results = [json.load(open(loc)) for loc in im_block6_results_locs]
# im_block6_df = pd.DataFrame(data=im_block6_results)
# im_block6_df['method'] = 'Imagenet Finetuned Block6+'

# # in progress
# im_all_results_locs = glob.glob(os.path.join(results_dir, 'imagenet_finetune','imagenet_finetune_all_nocheat_b256_1em5*_finetuned_result_timestamped*.json'))
# im_all_results = [json.load(open(loc)) for loc in im_all_results_locs]
# im_all_df = pd.DataFrame(data=im_all_results)
# im_all_df['method'] = 'Imagenet Finetuned All'

# print(len(im_scratch_df), len(im_frozen_df),len(im_block6_df), len(im_block4_df), len(im_all_df))  # todo 6

# %%
# scratch_results_locs = glob.glob(os.path.join(results_dir, 'gz_scratch', 'gz_scratch_b256_1em5*scratch_result_timestamped*.json'))
# scratch_results = [json.load(open(loc)) for loc in scratch_results_locs]
# scratch_df = pd.DataFrame(data=scratch_results)
# scratch_df['method'] = 'Scratch'

# # block6, block7, blocktop all good
# frozen_results_locs = glob.glob(os.path.join(results_dir, 'gz_finetune','gz_finetune_*_nocheat_b256_1em5*transfer_result_timestamped*.json'))
# frozen_results = [json.load(open(loc)) for loc in frozen_results_locs]
# frozen_df = pd.DataFrame(data=frozen_results)
# frozen_df['method'] = 'GZ Frozen'

# top_results_locs = glob.glob(os.path.join(results_dir, 'gz_finetune','gz_finetune_top_nocheat_b256_1em5*finetuned_result_timestamped*.json'))
# top_results = [json.load(open(loc)) for loc in top_results_locs]
# top_df = pd.DataFrame(data=top_results)
# top_df['method'] = 'GZ Finetuned Top'

# block7_results_locs = glob.glob(os.path.join(results_dir, 'gz_finetune','gz_finetune_block7_nocheat_b256_1em5*finetuned_result_timestamped*.json'))
# block7_results = [json.load(open(loc)) for loc in block7_results_locs]
# block7_df = pd.DataFrame(data=block7_results)
# block7_df['method'] = 'GZ Finetuned Block7+'

# block6_results_locs = glob.glob(os.path.join(results_dir, 'gz_finetune','gz_finetune_block6_nocheat_b256_1em5*_finetuned_result_timestamped*.json'))
# block6_results = [json.load(open(loc)) for loc in block6_results_locs]
# block6_df = pd.DataFrame(data=block6_results)
# block6_df['method'] = 'GZ Finetuned Block6+'

# block4_results_locs = glob.glob(os.path.join(results_dir, 'gz_finetune','gz_finetune_block4_nocheat_b256_1em5*_finetuned_result_timestamped*.json'))
# block4_results = [json.load(open(loc)) for loc in block4_results_locs]
# block4_df = pd.DataFrame(data=block4_results)
# block4_df['method'] = 'GZ Finetuned Block4+'


# all_results_locs = glob.glob(os.path.join(results_dir, 'gz_finetune','gz_finetune_all_nocheat_b256_1em5*finetuned_result_timestamped*.json'))
# all_results = [json.load(open(loc)) for loc in all_results_locs]
# all_df = pd.DataFrame(data=all_results)
# all_df['method'] = 'GZ Finetuned All'

# len(scratch_df), len(block7_df), len(block6_df), len(top_df), len(all_df)

# %%
# Multi-task

# finetune_review_unfreeze_top_* are probably okay and correct, but remade anyway

frozen_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_multi_task_unfreeze_*/*transfer*.json'))  # will be more
frozen_results = [json.load(open(loc)) for loc in frozen_results_locs]
frozen_df = pd.DataFrame(data=frozen_results)
frozen_df['method'] = 'GZM Frozen'

top_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_multi_task_unfreeze_top_*/*finetuned*.json'))
top_results = [json.load(open(loc)) for loc in top_results_locs]
top_df = pd.DataFrame(data=top_results)
top_df['method'] = 'GZM Finetuned Top'

six_plus_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_multi_task_unfreeze_6_plus_*/*finetuned*.json'))
six_plus_results = [json.load(open(loc)) for loc in six_plus_results_locs]
six_plus_df = pd.DataFrame(data=six_plus_results)
six_plus_df['method'] = 'GZM Finetuned 6+'

four_plus_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_multi_task_unfreeze_4_plus_*/*finetuned*.json'))
four_plus_results = [json.load(open(loc)) for loc in four_plus_results_locs]
four_plus_df = pd.DataFrame(data=four_plus_results)
four_plus_df['method'] = 'GZM Finetuned 4+'

all_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_multi_task_unfreeze_all_*/*finetuned*.json'))
all_results = [json.load(open(loc)) for loc in all_results_locs]
all_df = pd.DataFrame(data=all_results)
all_df['method'] = 'GZM Finetuned All'

print(len(frozen_df), len(top_df), len(six_plus_df), len(four_plus_df), len(all_df))
# Out:
# 240 60 60 60 60

# %%
# Single task

smooth_frozen_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_single_task_unfreeze_*/*transfer*.json'))  # will be more
smooth_frozen_results = [json.load(open(loc)) for loc in smooth_frozen_results_locs]
smooth_frozen_df = pd.DataFrame(data=smooth_frozen_results)
smooth_frozen_df['method'] = 'GZ Smooth Frozen'

smooth_top_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_single_task_unfreeze_topv2_*/*finetuned*.json'))  # was first run from the wrong checkpoint, hence v2 with that fix
smooth_top_results = [json.load(open(loc)) for loc in smooth_top_results_locs]
smooth_top_df = pd.DataFrame(data=smooth_top_results)
smooth_top_df['method'] = 'GZ Smooth Finetuned Top'

smooth_six_plus_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_single_task_unfreeze_6_plus_*/*finetuned*.json'))
smooth_six_plus_results = [json.load(open(loc)) for loc in smooth_six_plus_results_locs]
smooth_six_plus_df = pd.DataFrame(data=smooth_six_plus_results)
smooth_six_plus_df['method'] = 'GZ Smooth Finetuned 6+'

smooth_four_plus_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_single_task_unfreeze_4_plus_*/*finetuned*.json'))
smooth_four_plus_results = [json.load(open(loc)) for loc in smooth_four_plus_results_locs]
smooth_four_plus_df = pd.DataFrame(data=smooth_four_plus_results)
smooth_four_plus_df['method'] = 'GZ Smooth Finetuned 4+'

smooth_all_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_single_task_unfreeze_all_*/*finetuned*.json'))
smooth_all_results = [json.load(open(loc)) for loc in smooth_all_results_locs]
smooth_all_df = pd.DataFrame(data=smooth_all_results)
smooth_all_df['method'] = 'GZ Smooth Finetuned All'

print(len(smooth_frozen_df), len(smooth_top_df), len(smooth_six_plus_df), len(smooth_four_plus_df), len(smooth_all_df))
# Out:
# 240 60 60 60 60

# %%
# Imagenet

imagenet_frozen_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_imagenet_unfreeze_*/*transfer*.json'))  # will be more
imagenet_frozen_results = [json.load(open(loc)) for loc in imagenet_frozen_results_locs]
imagenet_frozen_df = pd.DataFrame(data=imagenet_frozen_results)
imagenet_frozen_df['method'] = 'Imagenet Frozen'

imagenet_top_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_imagenet_unfreeze_top_*/*finetuned*.json'))  # was first run from the wrong checkpoint, hence v2 with that fix
imagenet_top_results = [json.load(open(loc)) for loc in imagenet_top_results_locs]
imagenet_top_df = pd.DataFrame(data=imagenet_top_results)
imagenet_top_df['method'] = 'Imagenet Finetuned Top'

imagenet_six_plus_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_imagenet_unfreeze_6plus_*/*finetuned*.json'))
imagenet_six_plus_results = [json.load(open(loc)) for loc in imagenet_six_plus_results_locs]
imagenet_six_plus_df = pd.DataFrame(data=imagenet_six_plus_results)
imagenet_six_plus_df['method'] = 'Imagenet Finetuned 6+'

imagenet_four_plus_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_imagenet_unfreeze_4plus_*/*finetuned*.json'))
imagenet_four_plus_results = [json.load(open(loc)) for loc in imagenet_four_plus_results_locs]
imagenet_four_plus_df = pd.DataFrame(data=imagenet_four_plus_results)
imagenet_four_plus_df['method'] = 'Imagenet Finetuned 4+'

imagenet_all_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_imagenet_unfreeze_all_*/*finetuned*.json'))
imagenet_all_results = [json.load(open(loc)) for loc in imagenet_all_results_locs]
imagenet_all_df = pd.DataFrame(data=imagenet_all_results)
imagenet_all_df['method'] = 'Imagenet Finetuned All'

print(len(imagenet_frozen_df), len(imagenet_top_df), len(imagenet_six_plus_df), len(imagenet_four_plus_df), len(imagenet_all_df))
# Out:
# 240 60 60 60 60

# %%
# from scratch (only "all", implicitly)
# very possibly trained with colour accidentally...

scratch_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_scratch_*/*.json'))
scratch_results = [json.load(open(loc)) for loc in scratch_results_locs]
scratch_df = pd.DataFrame(data=scratch_results)
scratch_df['method'] = 'Scratch'

print(len(scratch_df))
# Out:
# 60

# %%
# Bar task

bar_frozen_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_bar_*/*transfer*.json'))  # will be more
bar_frozen_results = [json.load(open(loc)) for loc in bar_frozen_results_locs]
bar_frozen_df = pd.DataFrame(data=bar_frozen_results)
bar_frozen_df['method'] = 'GZ Bar Frozen'

# bar_top_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_bar_top_*/*finetuned*.json'))  # was first run from the wrong checkpoint, hence v2 with that fix
# bar_top_results = [json.load(open(loc)) for loc in bar_top_results_locs]
# bar_top_df = pd.DataFrame(data=bar_top_results)
# bar_top_df['method'] = 'GZS Finetuned Top'

# bar_six_plus_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_bar_6_plus_*/*finetuned*.json'))
# bar_six_plus_results = [json.load(open(loc)) for loc in bar_six_plus_results_locs]
# bar_six_plus_df = pd.DataFrame(data=bar_six_plus_results)
# bar_six_plus_df['method'] = 'GZS Finetuned 6+'

# bar_four_plus_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_bar_4_plus_*/*finetuned*.json'))
# bar_four_plus_results = [json.load(open(loc)) for loc in bar_four_plus_results_locs]
# bar_four_plus_df = pd.DataFrame(data=bar_four_plus_results)
# bar_four_plus_df['method'] = 'GZS Finetuned 4+'

bar_all_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_bar_all_*/*finetuned*.json'))
bar_all_results = [json.load(open(loc)) for loc in bar_all_results_locs]
bar_all_df = pd.DataFrame(data=bar_all_results)
bar_all_df['method'] = 'GZ Bar Finetuned All'

# print(len(bar_frozen_df), len(bar_top_df), len(bar_six_plus_df), len(bar_four_plus_df), len(bar_all_df))
print(len(bar_frozen_df), len(bar_all_df))
# Out:
# 60 60

# %%
# bulge task

bulge_frozen_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_bulge_size_*/*transfer*.json'))  # will be more
bulge_frozen_results = [json.load(open(loc)) for loc in bulge_frozen_results_locs]
bulge_frozen_df = pd.DataFrame(data=bulge_frozen_results)
bulge_frozen_df['method'] = 'GZ Bulge Frozen'

# bulge_top_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_bulge_size_top_*/*finetuned*.json'))  # was first run from the wrong checkpoint, hence v2 with that fix
# bulge_top_results = [json.load(open(loc)) for loc in bulge_top_results_locs]
# bulge_top_df = pd.DataFrame(data=bulge_top_results)
# bulge_top_df['method'] = 'GZS Finetuned Top'

# bulge_six_plus_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_bulge_size_6_plus_*/*finetuned*.json'))
# bulge_six_plus_results = [json.load(open(loc)) for loc in bulge_six_plus_results_locs]
# bulge_six_plus_df = pd.DataFrame(data=bulge_six_plus_results)
# bulge_six_plus_df['method'] = 'GZS Finetuned 6+'

# bulge_four_plus_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_bulge_size_4_plus_*/*finetuned*.json'))
# bulge_four_plus_results = [json.load(open(loc)) for loc in bulge_four_plus_results_locs]
# bulge_four_plus_df = pd.DataFrame(data=bulge_four_plus_results)
# bulge_four_plus_df['method'] = 'GZS Finetuned 4+'

bulge_all_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_bulge_size_all_*/*finetuned*.json'))
bulge_all_results = [json.load(open(loc)) for loc in bulge_all_results_locs]
bulge_all_df = pd.DataFrame(data=bulge_all_results)
bulge_all_df['method'] = 'GZ Bulge Finetuned All'

# print(len(bulge_frozen_df), len(bulge_top_df), len(bulge_six_plus_df), len(bulge_four_plus_df), len(bulge_all_df))
print(len(bulge_frozen_df), len(bulge_all_df))
# Out:
# 60 60

# %%
# spiral task

spiral_frozen_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_spiral_*/*transfer*.json'))  # will be more
spiral_frozen_results = [json.load(open(loc)) for loc in spiral_frozen_results_locs]
spiral_frozen_df = pd.DataFrame(data=spiral_frozen_results)
spiral_frozen_df['method'] = 'GZ Spiral Frozen'

# spiral_top_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_spiral_size_top_*/*finetuned*.json'))  # was first run from the wrong checkpoint, hence v2 with that fix
# spiral_top_results = [json.load(open(loc)) for loc in spiral_top_results_locs]
# spiral_top_df = pd.DataFrame(data=spiral_top_results)
# spiral_top_df['method'] = 'GZS Finetuned Top'

# spiral_six_plus_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_spiral_size_6_plus_*/*finetuned*.json'))
# spiral_six_plus_results = [json.load(open(loc)) for loc in spiral_six_plus_results_locs]
# spiral_six_plus_df = pd.DataFrame(data=spiral_six_plus_results)
# spiral_six_plus_df['method'] = 'GZS Finetuned 6+'

# spiral_four_plus_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_spiral_size_4_plus_*/*finetuned*.json'))
# spiral_four_plus_results = [json.load(open(loc)) for loc in spiral_four_plus_results_locs]
# spiral_four_plus_df = pd.DataFrame(data=spiral_four_plus_results)
# spiral_four_plus_df['method'] = 'GZS Finetuned 4+'

spiral_all_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_spiral_all_*/*finetuned*.json'))
spiral_all_results = [json.load(open(loc)) for loc in spiral_all_results_locs]
spiral_all_df = pd.DataFrame(data=spiral_all_results)
spiral_all_df['method'] = 'GZ Spiral Finetuned All'

# print(len(spiral_frozen_df), len(spiral_top_df), len(spiral_six_plus_df), len(spiral_four_plus_df), len(spiral_all_df))
print(len(spiral_frozen_df), len(spiral_all_df))
# Out:
# 60 60

# %%
# single_frozen_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_unfreeze_top_*/*transfer*.json'))
# single_frozen_results = [json.load(open(loc)) for loc in single_frozen_results_locs]
# single_frozen_df = pd.DataFrame(data=single_frozen_results)
# single_frozen_df['method'] = 'GZS Frozen'
# len(single_frozen_df)

# single_top_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review','finetune_review_single_task_unfreeze_topv2_*/*finetuned*.json'))
# single_top_results = [json.load(open(loc)) for loc in single_top_results_locs]
# single_top_df = pd.DataFrame(data=single_top_results)
# single_top_df['method'] = 'GZS Finetuned Top'
# len(single_top_df)

# im_top_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review', 'finetune_review_imagenet_unfreeze_top_*/*finetuned*.json'))
# im_top_results = [json.load(open(loc)) for loc in im_top_results_locs]
# im_top_df = pd.DataFrame(data=im_top_results)
# im_top_df['method'] = 'Imagenet Finetuned Top'

# im_frozen_results_locs = glob.glob(os.path.join(results_dir, 'finetune_review', 'finetune_review_imagenet_unfreeze_top_*/*transfer*.json'))
# im_frozen_results = [json.load(open(loc)) for loc in im_frozen_results_locs]
# im_frozen_df = pd.DataFrame(data=im_frozen_results)
# im_frozen_df['method'] = 'Imagenet Finetuned Top'

# print(len(top_df), len(single_top_df), len(im_top_df))

# print(len(frozen_df), len(single_frozen_df), len(im_frozen_df))

# %%
# small_results_locs = glob.glob(os.path.join(results_dir, 'small_rng', 'small_rng*timestamped*.json'))
# small_results = [json.load(open(loc)) for loc in small_results_locs]


# small_df = pd.DataFrame(data=small_results)
# small_df['method'] = 'small'
# small_df.head()

# %%
# scratch_results_locs = glob.glob('/Users/walml/repos/zoobot/finetune_from_scratch*timestamped*.json')
# scratch_results = [json.load(open(loc)) for loc in scratch_results_locs]

# scratch_df = pd.DataFrame(data=scratch_results)
# scratch['method'] = 'scratch'

# %%
plt.figure(figsize=(24, 16))

# y_col = 'mean_loss'
y_col = 'mean_acc'

# plt.semilogx(all_df['train_dataset_size'], all_df[y_col], linestyle='', marker='+', label='W+21 All')
# plt.semilogx(top_df['train_dataset_size'], top_df[y_col], linestyle='', marker='+', label='W+21 Top')
plt.semilogx(frozen_df['train_dataset_size'], frozen_df[y_col], linestyle='', marker='+', label='W+21 Frozen')
# FT top does almost nothing for decals, representation doesn't need adapting

# plt.semilogx(smooth_top_df['train_dataset_size'], smooth_top_df[y_col], linestyle='', marker='+', label='W+21 STop')
plt.semilogx(smooth_frozen_df['train_dataset_size'], smooth_frozen_df[y_col], linestyle='', marker='+', label='W+21 Smooth Frozen')
# plt.semilogx(smooth_all_df['train_dataset_size'], smooth_all_df[y_col], linestyle='', marker='+', label='W+21 Smooth All')
# FT top makes HUGE difference for single task, representation very easily adapted

plt.semilogx(imagenet_frozen_df['train_dataset_size'], imagenet_frozen_df[y_col], linestyle='', marker='+', label='Imagenet Frozen')
# plt.semilogx(imagenet_top_df['train_dataset_size'], imagenet_top_df[y_col], linestyle='', marker='+', label='Imagenet Top')
# plt.semilogx(imagenet_all_df['train_dataset_size'], imagenet_all_df[y_col], linestyle='', marker='+', label='Imagenet All')
# FT top makes moderate difference for imagenet, representation needs significant adaption

# plt.semilogx(bar_all_df['train_dataset_size'], bar_all_df[y_col], linestyle='', marker='+', label='W+21 Bar All')
plt.semilogx(bar_frozen_df['train_dataset_size'], bar_frozen_df[y_col], linestyle='', marker='+', label='W+21 Bar Frozen')
# FT top makes HUGE difference for single task, representation very easily adapted

plt.semilogx(bulge_frozen_df['train_dataset_size'], bulge_frozen_df[y_col], linestyle='', marker='+', label='W+21 Bulge Frozen')

plt.semilogx(spiral_frozen_df['train_dataset_size'], spiral_frozen_df[y_col], linestyle='', marker='+', label='W+21 Spiral Frozen')

plt.xlabel('Dataset Size')
plt.ylabel(y_col)
# plt.legend(loc='lower left')
plt.legend(loc='upper left')

# %%
plt.figure(figsize=(24, 16))

plt.semilogx(all_df['train_dataset_size'], all_df[y_col], linestyle='', marker='+', label='W+21 All')
# plt.semilogx(top_df['train_dataset_size'], top_df[y_col], linestyle='', marker='+', label='W+21 Top')
# plt.semilogx(frozen_df['train_dataset_size'], frozen_df[y_col], linestyle='', marker='+', label='W+21 Frozen')
# FT top does almost nothing for decals, representation doesn't need adapting

# plt.semilogx(single_top_df['train_dataset_size'], single_top_df[y_col], linestyle='', marker='+', label='W+21 STop')
# plt.semilogx(single_frozen_df['train_dataset_size'], single_frozen_df[y_col], linestyle='', marker='+', label='W+21 GZS Frozen')
plt.semilogx(smooth_all_df['train_dataset_size'], smooth_all_df[y_col], linestyle='', marker='+', label='W+21 Smooth All')
# FT top makes HUGE difference for single task, representation very easily adapted

# plt.semilogx(imagenet_frozen_df['train_dataset_size'], imagenet_frozen_df[y_col], linestyle='', marker='+', label='Imagenet Frozen')
# plt.semilogx(imagenet_top_df['train_dataset_size'], imagenet_top_df[y_col], linestyle='', marker='+', label='Imagenet Top')
plt.semilogx(imagenet_all_df['train_dataset_size'], imagenet_all_df[y_col], linestyle='', marker='+', label='Imagenet All')
# FT top makes moderate difference for imagenet, representation needs significant adaption

plt.semilogx(bar_all_df['train_dataset_size'], bar_all_df[y_col], linestyle='', marker='+', label='W+21 Bar All')
# plt.semilogx(bar_frozen_df['train_dataset_size'], bar_frozen_df[y_col], linestyle='', marker='+', label='W+21 Bar Frozen')
# FT top makes HUGE difference for single task, representation very easily adapted

plt.semilogx(bulge_all_df['train_dataset_size'], bulge_all_df[y_col], linestyle='', marker='+', label='W+21 Bulge All')

plt.semilogx(spiral_all_df['train_dataset_size'], spiral_all_df[y_col], linestyle='', marker='+', label='W+21 Spiral All')

plt.xlabel('Dataset Size')
plt.ylabel(y_col)
# plt.legend(loc='lower left')
plt.legend(loc='upper left')

# %%
# sns.set_context('talk')
plt.figure(figsize=(24, 16))
# plt.semilogx(precalculated_df['train_dataset_size'], precalculated_df[y_col], linestyle='', marker='+', label='W+21 Precalculated')
plt.semilogx(frozen_df['train_dataset_size'], frozen_df[y_col], linestyle='', marker='+', label='W+21 Frozen')
# plt.semilogx(scratch_df['train_dataset_size'], scratch_df[y_col], linestyle='', marker='+', label='Scratch')

# plt.semilogx(small_df['train_dataset_size'], small_df[y_col], linestyle='', marker='+', label='Small')

plt.semilogx(top_df['train_dataset_size'], top_df[y_col], linestyle='', marker='+', label='W+21 Top')
# plt.semilogx(block7_df['train_dataset_size'], block7_df[y_col], linestyle='', marker='+', label='W+21 Block7')
plt.semilogx(six_plus_df['train_dataset_size'], six_plus_df[y_col], linestyle='', marker='+', label='W+21 Block6')
plt.semilogx(four_plus_df['train_dataset_size'], four_plus_df[y_col], linestyle='', marker='+', label='W+21 Block4')
plt.semilogx(all_df['train_dataset_size'], all_df[y_col], linestyle='', marker='+', label='W+21 All')

plt.semilogx(imagenet_frozen_df['train_dataset_size'], imagenet_frozen_df[y_col], linestyle='', marker='+', label='Imagenet Frozen')
# plt.semilogx(im_block6_df['train_dataset_size'], im_block6_df[y_col], linestyle='', marker='+', label='Imagenet Block6')
plt.semilogx(imagenet_four_plus_df['train_dataset_size'], imagenet_four_plus_df[y_col], linestyle='', marker='+', label='Imagenet Block4')
plt.semilogx(imagenet_all_df['train_dataset_size'], imagenet_all_df[y_col], linestyle='', marker='+', label='Imagenet All')

plt.xlabel('Dataset Size')
plt.ylabel(y_col)
# plt.legend(loc='lower left')
plt.legend(loc='upper right')

# %%
# block7_df

# %%
# df = pd.concat([precalculated_df, frozen_df, scratch_df, imagenet_df, small_df], axis=0)
# df = pd.concat([block7_df, block6_df, scratch_df, top_df], axis=0)
# df = pd.concat([frozen_df, block7_df], axis=0)
# df = pd.concat([frozen_df, block6_df], axis=0)

gzm_data = [
    scratch_df,
    frozen_df,
    top_df,
    # block7_df,
    six_plus_df,
    four_plus_df,
    all_df
]

gzs_data = [
    scratch_df,
    smooth_frozen_df,
    smooth_top_df,
    # block7_df,
    smooth_six_plus_df,
    smooth_four_plus_df,
    smooth_all_df
]

im_data = [
    # im_scratch_df,
    imagenet_frozen_df,
    imagenet_six_plus_df,
    imagenet_four_plus_df,
    imagenet_all_df
]

df = pd.concat(gzm_data + gzs_data + im_data).reset_index(drop=True)
len(df)
# Out:
# 1500

# %%
# ring_galaxy_size = {
#     3: 2,
#     8: 5,
#     21:  13,
#     58:  33,
#     159: 79,
#     438: 197,
#     1207: ,
#     3327: ,
#     9167: ,
#     25263: ,
#     69620: 
# }

unique_ring_galaxy_size = {
    3: 2,
    8: 5,
    21:  13,
    58:  33,
    159: 79,  # of 79
    438: 197,  # of 197
    1207: 575,  # of 595
    3327: 1478,  # of 1626
    9167: 3520,  # of 4620
    25263: 6190,  # of 12747
    69620: 6962  # of 34810
}
    
df['unique_train_rings'] = df['train_dataset_size'].apply(lambda x: unique_ring_galaxy_size.get(x, np.nan))
scratch_df['unique_train_rings'] = scratch_df['train_dataset_size'].apply(lambda x: unique_ring_galaxy_size.get(x, np.nan))

# %%
df.sample(10)
# Out:
#       batch_size  mean_loss  mean_acc  \
# 70           256   0.343730  0.857100
# 990          256   0.625300  0.722267
# 976          256   0.768484  0.484300
# 725          256   0.699216  0.519083
# 184          256   0.303967  0.872267
# 589          256   0.693456  0.495750
# 1367         256   0.465034  0.801267
# 294          256   0.684427  0.511367
# 885          256   0.709737  0.494517
# 159          256   0.303774  0.869883
#
#                                             predictions  \
# 70    [0.9433804750442505, 0.18096399307250977, 0.38...
# 990   [0.7314715385437012, 0.5938512682914734, 0.399...
# 976   [0.49972644448280334, 0.4986935555934906, 0.49...
# 725   [0.4961400032043457, 0.4909873306751251, 0.481...
# 184   [0.981812059879303, 0.08730702102184296, 0.256...
# 589   [0.5088786482810974, 0.5088780522346497, 0.508...
# 1367  [0.7282133102416992, 0.06608342379331589, 0.30...
# 294   [0.48195067048072815, 0.4917142689228058, 0.47...
# ...

# %%
sns.set_context('notebook')
ax = sns.lineplot(data=df, x='train_dataset_size', y='mean_loss', hue='method', marker='+')
ax.set_xscale('log')

# %%
sns.set_context('notebook')
ax = sns.lineplot(data=df, x='unique_train_rings', y='mean_loss', hue='method', marker='+')
ax.set_xscale('log')
plt.ylabel('Mean Loss')
plt.xlabel('Ring Galaxies to Train On')
# Out:
# Text(0.5, 0, 'Ring Galaxies to Train On')

# %%
sns.set_context('notebook')
ax = sns.lineplot(data=df, x='unique_train_rings', y='mean_loss', hue='method', marker='+')
ax.set_xscale('log')
plt.ylabel('Mean Loss')
plt.xlabel('Ring Galaxies to Train On')
plt.xlim(10**3, 10**4)
plt.ylim(0.29, 0.35)
# Out:
# (0.29, 0.35)

# %%
# Paper figures

# %%
with sns.color_palette("mako") as colors:

        
    y_column = 'mean_acc'
    # y_column = 'mean_loss'

    imagenet_finetuning = pd.concat([imagenet_frozen_df, imagenet_top_df, imagenet_six_plus_df, imagenet_four_plus_df, imagenet_all_df], axis=0).reset_index(drop=True)
    imagenet_finetuning['unique_train_rings'] = imagenet_finetuning['train_dataset_size'].apply(lambda x: unique_ring_galaxy_size.get(x, np.nan))
    ax = sns.lineplot(data=imagenet_finetuning, x='unique_train_rings', y=y_column, hue='method', marker='.', markersize=10, palette='mako')

    ax.set_xscale('log')
    plt.xlabel('Ring Galaxies to Train On')
    # plt.xlim(10**3, 10**4)

    if y_column == 'mean_loss':
        plt.ylabel('Mean Loss')
        plt.ylim(0.27, 0.35)
    else:
        plt.ylabel('Mean Accuracy')
        # plt.ylim(0.86, 0.9)
        plt.ylim(0.7, 0.9)


    plt.legend(loc='lower left')
    
#     https://stackoverflow.com/questions/52278350/seaborn-dashed-line-not-dashed-in-the-legend
    # leg = ax.legend()
    # leg_lines = leg.get_lines()
    # leg_lines[-1].set_linestyle("--")
    
    
    # leg_text = leg.get_texts()
    # leg_text[1].set_text('GZ FT Top')
    # leg_text[2].set_text('GZ FT Blocks 6+')
    # leg_text[3].set_text('GZ FT Blocks 4+')
    # leg_text[4].set_text('GZ FT All')
    
#     block7_df removed for clarity

    # plt.savefig('loss_by_rings_zoomed.pdf')
    # plt.savefig('loss_by_rings_zoomed.png')

# %%
with sns.color_palette("mako") as colors:

        
    y_column = 'mean_acc'
    # y_column = 'mean_loss'

    multi_finetuning = pd.concat([frozen_df, top_df, six_plus_df, four_plus_df, all_df], axis=0).reset_index(drop=True)
    multi_finetuning['unique_train_rings'] = multi_finetuning['train_dataset_size'].apply(lambda x: unique_ring_galaxy_size.get(x, np.nan))
    ax = sns.lineplot(data=multi_finetuning, x='unique_train_rings', y=y_column, hue='method', marker='.', markersize=10)

    smooth_finetuning = pd.concat([smooth_frozen_df, smooth_top_df, smooth_six_plus_df, smooth_four_plus_df, smooth_all_df], axis=0).reset_index(drop=True)
    smooth_finetuning['unique_train_rings'] = smooth_finetuning['train_dataset_size'].apply(lambda x: unique_ring_galaxy_size.get(x, np.nan))
    ax = sns.lineplot(data=smooth_finetuning, x='unique_train_rings', y=y_column, hue='method', marker='.', markersize=10, palette='rocket')

    # imagenet_finetuning = pd.concat([imagenet_frozen_df, imagenet_top_df, imagenet_six_plus_df, imagenet_four_plus_df, imagenet_all_df], axis=0).reset_index(drop=True)
    # imagenet_finetuning['unique_train_rings'] = imagenet_finetuning['train_dataset_size'].apply(lambda x: unique_ring_galaxy_size.get(x, np.nan))
    # ax = sns.lineplot(data=imagenet_finetuning, x='unique_train_rings', y=y_column, hue='method', marker='.', markersize=10, palette='mako')
    
#     ax = sns.lineplot(
#         data=scratch_df,
#         x='unique_train_rings', y=y_column, hue='method', marker='.', markersize=10, linestyle='--',  palette=sns.color_palette('mako', 6)[:1])
# #     ax.scatter(6962, scratch_df.query('train_dataset_size == 69620')['mean_loss'].mean())


    ax.set_xscale('log')
    plt.xlabel('Ring Galaxies to Train On')
    # plt.xlim(10**3, 10**4)

    if y_column == 'mean_loss':
        plt.ylabel('Mean Loss')
        plt.ylim(0.27, 0.35)
    else:
        plt.ylabel('Mean Accuracy')
        # plt.ylim(0.86, 0.9)
        plt.ylim(0.7, 0.9)


    plt.legend(loc='lower left')
    
#     https://stackoverflow.com/questions/52278350/seaborn-dashed-line-not-dashed-in-the-legend
    # leg = ax.legend()
    # leg_lines = leg.get_lines()
    # leg_lines[-1].set_linestyle("--")
    
    
    # leg_text = leg.get_texts()
    # leg_text[1].set_text('GZ FT Top')
    # leg_text[2].set_text('GZ FT Blocks 6+')
    # leg_text[3].set_text('GZ FT Blocks 4+')
    # leg_text[4].set_text('GZ FT All')
    
#     block7_df removed for clarity

    # plt.savefig('loss_by_rings_zoomed.pdf')
    # plt.savefig('loss_by_rings_zoomed.png')

    # is it possible that gzs frozen or gzs finetuned are duplicates?

# %%
# palette_multi = sns.cubehelix_palette(start=1.9, rot=-.7, n_colors=5, light=.7, reverse=True)
# palette_multi
palette_multi = sns.color_palette('mako', n_colors=5)

# %%
fig, axes = plt.subplots(ncols=3, figsize=(13, 4), sharex=True, sharey=True)

sns.set_theme(context='paper', style='ticks', font_scale=1.4) # font_scale=1.2
# sns.set_style('ticks', {'legend.frameon':True})
# sns.set_context('notebook')


ax = axes[0]
    
y_column = 'mean_acc'
# y_column = 'mean_loss'

if y_column == 'mean_loss':
    ax.set_ylabel('Mean Loss')
    ax.set_ylim(0.27, 0.35)
else:
    ax.set_ylabel('Mean Accuracy')
    # plt.ylim(0.86, 0.9)
    ax.set_ylim(0.5, 0.9)




imagenet_finetuning = pd.concat([imagenet_frozen_df, imagenet_top_df, imagenet_six_plus_df, imagenet_four_plus_df, imagenet_all_df], axis=0).reset_index(drop=True)
imagenet_finetuning['unique_train_rings'] = imagenet_finetuning['train_dataset_size'].apply(lambda x: unique_ring_galaxy_size.get(x, np.nan))
sns.lineplot(data=imagenet_finetuning, x='unique_train_rings', y=y_column, hue='method', marker='.', markersize=10, palette='rocket', ax=ax)


leg = ax.legend(loc='upper left')
leg_text = leg.get_texts()
leg_text[0].set_text('Frozen')
leg_text[1].set_text('FT Top')
leg_text[2].set_text('FT Blocks 6+')
leg_text[3].set_text('FT Blocks 4+')
leg_text[4].set_text('FT All')
ax.set_title('Imagenet')



ax = axes[1]
smooth_finetuning = pd.concat([smooth_frozen_df, smooth_top_df, smooth_six_plus_df, smooth_four_plus_df, smooth_all_df], axis=0).reset_index(drop=True)
smooth_finetuning['unique_train_rings'] = smooth_finetuning['train_dataset_size'].apply(lambda x: unique_ring_galaxy_size.get(x, np.nan))
sns.lineplot(data=smooth_finetuning, x='unique_train_rings', y=y_column, hue='method', marker='.', markersize=10, palette='rocket', ax=ax)

leg = ax.legend(loc='upper left')
leg_text = leg.get_texts()
leg_text[0].set_text('Frozen')
leg_text[1].set_text('FT Top')
leg_text[2].set_text('FT Blocks 6+')
leg_text[3].set_text('FT Blocks 4+')
leg_text[4].set_text('FT All')
ax.set_title('GZ Smooth Task Only')


ax = axes[2]
multi_finetuning = pd.concat([frozen_df, top_df, six_plus_df, four_plus_df, all_df], axis=0).reset_index(drop=True)
multi_finetuning['unique_train_rings'] = multi_finetuning['train_dataset_size'].apply(lambda x: unique_ring_galaxy_size.get(x, np.nan))
sns.lineplot(data=multi_finetuning, x='unique_train_rings', y=y_column, hue='method', marker='.', markersize=10, ax=ax, palette='rocket')

leg = ax.legend(loc='lower right')
leg_text = leg.get_texts()
leg_text[0].set_text('Frozen')
leg_text[1].set_text('FT Top')
leg_text[2].set_text('FT Blocks 6+')
leg_text[3].set_text('FT Blocks 4+')
leg_text[4].set_text('FT All')
ax.set_title('GZ All Tasks')


#     ax = sns.lineplot(
#         data=scratch_df,
#         x='unique_train_rings', y=y_column, hue='method', marker='.', markersize=10, linestyle='--',  palette=sns.color_palette('mako', 6)[:1])
# #     ax.scatter(6962, scratch_df.query('train_dataset_size == 69620')['mean_loss'].mean())


for ax in axes:

    ax.set_xscale('log')
    ax.set_xlabel('Ring Galaxies to Train On')
    # plt.xlim(10**3, 10**4)

#     https://stackoverflow.com/questions/52278350/seaborn-dashed-line-not-dashed-in-the-legend
# leg = ax.legend()
# leg_lines = leg.get_lines()
# leg_lines[-1].set_linestyle("--")


#     block7_df removed for clarity

plt.tight_layout()

plt.savefig('finetuning_comparison.pdf')
plt.savefig('finetuning_comparison.png')

    # is it possible that gzs frozen or gzs finetuned are duplicates?

# %%
# Out:
# (0.2980392156862745, 0.4470588235294118, 0.6901960784313725)

# %%
# color_multi = sns.light_palette("#3892DF", 5)[-1:]
color_multi = sns.color_palette()[:1]
color_single = sns.light_palette("#DC4DFA", 5)[-1:]
color_imagenet = sns.light_palette("#FF3765", 5)[-1:]

color_scratch = [(0, 0, 0)]

# %%
color_imagenet
# Out:
# [(1.0, 0.21568627450980393, 0.396078431372549)]

# %%
# mako_then_rocket = mako_pair + green_pair + rocket_pair

# %%
from matplotlib.lines import Line2D
from matplotlib.legend import Legend

# %%
sns.set_theme(context='paper', style='ticks', font_scale=1.4) # font_scale=1.2

gz_vs_im = pd.concat([frozen_df, all_df, smooth_frozen_df, smooth_all_df, imagenet_frozen_df, imagenet_all_df], axis=0).reset_index(drop=True)
gz_vs_im['unique_train_rings'] = gz_vs_im['train_dataset_size'].apply(lambda x: unique_ring_galaxy_size.get(x, np.nan))

# y_column = 'mean_loss'
y_column = 'mean_acc'

dashes = {
    'Finetuned': (2, 2),
    'Frozen': (2, 0)
}

finetuned_line_style = 'dashed'

ax = sns.lineplot(
    data=gz_vs_im,
    x='unique_train_rings',
    y=y_column,
    hue='method',
    marker='.',
    markersize=10,
    # palette=mako_then_rocket[1:]
    palette=color_multi + color_multi + color_single + color_single + color_imagenet + color_imagenet,
    style=gz_vs_im['method'].apply(lambda x: 'Finetuned' if 'Finetuned' in x else 'Frozen'),
    dashes=dashes
)
ax = sns.lineplot(
    data=scratch_df,
    x='unique_train_rings',
    y=y_column,
    hue='method',
    marker='.',
    markersize=10,
    # palette=sns.color_palette('mako', 6)[:1],
    palette=color_scratch
    # linestyle='dotted'
)

# log space
# first param is line loc in data coordinates
# min and max are limits in plot coordinates (sigh)
# happily can manually align using each other
if y_column == 'mean_loss':
    # plt.axvline(10**3, ymax=0.166, color='k', linestyle=':', alpha=.3)
    # plt.axhline(0.35, xmin=0.737, color='k', linestyle=':', alpha=.3)
    plt.ylabel('Mean Loss')
else:
    # plt.axvline(10**3, ymin=0.8, color='k', linestyle=':', alpha=.3)
    # plt.axhline(0.8, xmin=0.737, color='k', linestyle=':', alpha=.3)
    plt.ylabel('Mean Accuracy')
    plt.ylim(0.5, 0.9)


ax.set_xscale('log')
plt.xlabel('Ring Galaxies to Train On')
# plt.xlim(10**3, 10**4)
# plt.ylim(0.29, 0.35)
# can include small_df but it clutters - best just with text I think?


color_lines = [
    Line2D([0], [0], color=color_multi[0]),
    Line2D([0], [0], color=color_single[0]),
    Line2D([0], [0], color=color_imagenet[0]),
    Line2D([0], [0], color=color_scratch[0]),
]

ft_lines = [ 
    Line2D([0], [0], color="grey"),
    Line2D([0], [0], color="grey", linestyle=finetuned_line_style, dashes=dashes['Finetuned'])
]

plt.legend(color_lines, ['GZ Multi', 'GZ Smooth', 'Imagenet', 'Scratch'], loc='upper left')

# leg = ax.legend(loc='lower left')
# leg_lines = leg.get_lines()
# leg_lines[-1].set_linestyle("dotted")

# leg_text = leg.get_texts()
# leg_text[1].set_text('GZ-Multi Fine-tuned')
# leg_text[3].set_text('GZ-Single Fine-tuned')
# leg_text[5].set_text('Imagenet Finetuned')


# Create the second legend and add the artist manually.
leg = Legend(ax, ft_lines, ['Frozen', 'Finetuned'],
             loc='lower right')
ax.add_artist(leg)

plt.tight_layout()
plt.savefig('accuracy_by_rings.pdf')
plt.savefig('accuracy_by_rings.png')

# %%
# TODO change to best single task

gz_vs_im = pd.concat([all_df, smooth_all_df, bar_all_df, bulge_all_df, spiral_all_df], axis=0).reset_index(drop=True)
gz_vs_im['unique_train_rings'] = gz_vs_im['train_dataset_size'].apply(lambda x: unique_ring_galaxy_size.get(x, np.nan))

# y_column = 'mean_loss'
y_column = 'mean_acc'

dashes = {
    'Finetuned': (2, 2),
    'Frozen': (2, 0)
}

finetuned_line_style = 'dashed'

hue_order = [
    'GZM Finetuned All',
    'GZ Spiral Finetuned All',
    'GZ Smooth Finetuned All',
    'GZ Bar Finetuned All',
    'GZ Bulge Finetuned All', 

]

ax = sns.lineplot(
    data=gz_vs_im,
    x='unique_train_rings',
    y=y_column,
    hue='method',
    marker='.',
    markersize=10,
    # palette=mako_then_rocket[1:]
    # palette=gz_green + gz_green + gzs_blue + gzs_blue + imagenet_red + imagenet_red,
    # style=gz_vs_im['method'].apply(lambda x: 'Finetuned' if 'Finetuned' in x else 'Frozen'),
    dashes=dashes,
    hue_order=hue_order
)

ax = sns.lineplot(
    data=scratch_df,
    x='unique_train_rings',
    y=y_column,
    hue='method',
    marker='.',
    markersize=10,
    # palette=sns.color_palette('mako', 6)[:1],
    palette=color_scratch
    # linestyle='dotted'
)

# # log space
# # first param is line loc in data coordinates
# # min and max are limits in plot coordinates (sigh)
# # happily can manually align using each other
# if y_column == 'mean_loss':
#     plt.axvline(10**3, ymax=0.166, color='k', linestyle=':', alpha=.3)
#     plt.axhline(0.35, xmin=0.737, color='k', linestyle=':', alpha=.3)
#     plt.ylabel('Mean Loss')
# else:
#     plt.axvline(10**3, ymin=0.8, color='k', linestyle=':', alpha=.3)
#     plt.axhline(0.8, xmin=0.737, color='k', linestyle=':', alpha=.3)
#     plt.ylabel('Mean Accuracy')


ax.set_xscale('log')
plt.xlabel('Ring Galaxies to Train On')
plt.ylabel('Mean Accuracy')
# plt.xlim(10**3, 10**4)
# plt.ylim(0.29, 0.35)
# can include small_df but it clutters - best just with text I think?


# color_lines = [
#     Line2D([0], [0], color=gz_green[0]),
#     Line2D([0], [0], color=gzs_blue[0]),
#     Line2D([0], [0], color=imagenet_red[0]),
#     Line2D([0], [0], color=scratch_color[0]),
# ]

# ft_lines = [ 
#     Line2D([0], [0], color="grey"),
#     Line2D([0], [0], color="grey", linestyle=finetuned_line_style, dashes=dashes['Finetuned'])
# ]

# plt.legend(color_lines, ['GZ Multi', 'GZ smooth', 'Imagenet', 'Scratch'], loc='upper left')

leg = ax.legend(loc='lower right')
# leg_lines = leg.get_lines()
# leg_lines[-1].set_linestyle("dotted")

leg_text = leg.get_texts()
leg_text[0].set_text('All Tasks')
leg_text[1].set_text('Spiral Only')
leg_text[2].set_text('Smooth Only')
leg_text[3].set_text('Bar Only')
leg_text[4].set_text('Bulge Only')

plt.ylim(0.5, 0.9)

plt.tight_layout()
plt.savefig('multi_question_comparison.pdf')
plt.savefig('multi_question_comparison.png')

# Create the second legend and add the artist manually.

# leg = Legend(ax, ft_lines, ['Frozen', 'Finetuned'],
#              loc='lower right')
# ax.add_artist(leg)

# %%
gz_vs_im['method'].value_counts()
# Out:
# GZM Finetuned All          60
# GZ Smooth Finetuned All    60
# GZ Bar Finetuned All       60
# GZ Bulge Finetuned All     60
# GZ Spiral Finetuned All    60
# Name: method, dtype: int64
